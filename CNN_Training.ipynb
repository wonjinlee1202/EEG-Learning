# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from keras.layers import Dense, Dropout, Conv1D, MaxPooling1D, Flatten, GRU
from keras.models import Sequential
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.losses import CategoricalCrossentropy
from keras.callbacks import EarlyStopping

def preprocess_data(data):
    # Unpack data
    X_train_valid = data['X_train_valid']
    y_train_valid = data['y_train_valid']
    X_test = data['X_test']
    y_test = data['y_test']

    # One-hot Encoding for y data
    encoder = LabelBinarizer()
    y_train_valid = encoder.fit_transform(y_train_valid)
    y_test = encoder.fit_transform(y_test)

    # Splitting training and validation data
    X_train, X_val, y_train, y_val = train_test_split(X_train_valid, y_train_valid, test_size=0.2, random_state=42)

    total_y_train = y_train
    total_y_val = y_val
    total_y_test = y_test

    # Trim
    X_train = X_train[:,:,0:800]
    X_val = X_val[:,:,0:800]
    X_test = X_test[:,:,0:800]

    # Maxpooling
    total_X_train = np.max(X_train.reshape(X_train.shape[0], X_train.shape[1], -1, 4), axis=3)
    total_X_val = np.max(X_val.reshape(X_val.shape[0], X_val.shape[1], -1, 4), axis=3)
    total_X_test = np.max(X_test.reshape(X_test.shape[0], X_test.shape[1], -1, 4), axis=3)

    # Validation and Test Data augmentation stops here (reshaping purposes)
    # Averaging and Subsampling below only apply to Training Data

    # Average every 4 time dumps
    X_train_average = np.mean(X_train.reshape(X_train.shape[0], X_train.shape[1], -1, 4), axis=3)
    X_train_average += np.random.normal(0.0, 0.5, X_train_average.shape)
    total_X_train = np.vstack((total_X_train, X_train_average))
    total_y_train = np.vstack((total_y_train, y_train))

    # Subsample every 4 time dumps
    for i in range(0, 4):
        X_train_subsample = X_train[:,:,i::4] + np.random.normal(0.0, 0.5, X_train[:,:,i::4].shape)
        total_X_train = np.vstack((total_X_train, X_train_subsample))
        total_y_train = np.vstack((total_y_train, y_train))

    return {'total_X_train': total_X_train, 'total_X_val': total_X_val, 'total_X_test': total_X_test, 'total_y_train': total_y_train, 'total_y_val': total_y_val, 'total_y_test': total_y_test}

# Load original data
data = dict()
X_train_valid = np.load("data/X_train_valid.npy")
y_train_valid = np.load("data/y_train_valid.npy")
X_test = np.load("data/X_test.npy")
y_test = np.load("data/y_test.npy")
person_train_valid = np.load("data/person_train_valid.npy")
person_test = np.load("data/person_test.npy")
data['X_train_valid'] = X_train_valid
data['y_train_valid'] = y_train_valid
data['X_test'] = X_test
data['y_test'] = y_test
data['person_train_valid'] = person_train_valid
data['person_test'] = person_test
preprocessed_data = preprocess_data(data)

# Load preprocessed data
X_train = preprocessed_data['total_X_train']
y_train = preprocessed_data['total_y_train']
X_val = preprocessed_data['total_X_val']
y_val = preprocessed_data['total_y_val']
X_test = preprocessed_data['total_X_test']
y_test = preprocessed_data['total_y_test']
X_train = np.transpose(X_train, (0, 2, 1))
X_val = np.transpose(X_val, (0, 2, 1))
X_test = np.transpose(X_test, (0, 2, 1))

# %%
CNN = Sequential()

CNN.add(Conv1D(22, 10, input_shape=(X_train.shape[1], X_train.shape[2]),padding='same', kernel_regularizer=l2(0.03)))
CNN.add(MaxPooling1D(2))
CNN.add(Dropout(0.5))
CNN.add(Conv1D(22, 10, input_shape=(X_train.shape[1]/2, X_train.shape[2]),padding='same', kernel_regularizer=l2(0.03)))
CNN.add(MaxPooling1D(2))
CNN.add(Dropout(0.5))
CNN.add(Flatten())
CNN.add(Dense(64))
CNN.add(Dropout(0.5))
CNN.add(Dense(4, activation='softmax'))

optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)

early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights=True)

CNN.compile(optimizer=optimizer, loss=CategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

CNN.summary()
print("Model compiled.")
# Out:
# /Users/wonjinlee/anaconda3/envs/ECEC147/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)               │ (None, 200, 22)        │         4,862 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 100, 22)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 100, 22)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 100, 22)        │         4,862 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 50, 22)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 50, 22)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1100)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │        70,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 80,448 (314.25 KB)
#  Trainable params: 80,448 (314.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Model compiled.

# %%
CNN_results = CNN.fit(X_train, y_train, epochs=150, batch_size=640, validation_data=(X_val, y_val), shuffle=True, verbose=1, callbacks=[early_stopping])

# Plotting accuracy trajectory
plt.plot(CNN_results.history['accuracy'])
plt.plot(CNN_results.history['val_accuracy'])
plt.title('CNN model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(CNN_results.history['loss'],'o')
plt.plot(CNN_results.history['val_loss'],'o')
plt.title('CNN model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# Epoch 1/150
# /Users/wonjinlee/anaconda3/envs/ECEC147/lib/python3.12/site-packages/keras/src/backend/tensorflow/nn.py:559: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 0.2567 - loss: 42.9496 - val_accuracy: 0.3168 - val_loss: 7.1298
# Epoch 2/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 250ms/step - accuracy: 0.2939 - loss: 18.1404 - val_accuracy: 0.3712 - val_loss: 4.8387
# Epoch 3/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - accuracy: 0.3419 - loss: 11.4459 - val_accuracy: 0.4350 - val_loss: 3.8241
# Epoch 4/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.3676 - loss: 8.3318 - val_accuracy: 0.4634 - val_loss: 3.5139
# Epoch 5/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.3951 - loss: 6.6970 - val_accuracy: 0.4823 - val_loss: 2.9351
# Epoch 6/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - accuracy: 0.3984 - loss: 5.7745 - val_accuracy: 0.4941 - val_loss: 2.6950
# Epoch 7/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - accuracy: 0.4239 - loss: 4.9552 - val_accuracy: 0.4965 - val_loss: 2.6348
# Epoch 8/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - accuracy: 0.4201 - loss: 4.5121 - val_accuracy: 0.5201 - val_loss: 2.4952
# Epoch 9/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - accuracy: 0.4293 - loss: 4.0935 - val_accuracy: 0.5272 - val_loss: 2.4125
# Epoch 10/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.4261 - loss: 3.8612 - val_accuracy: 0.5296 - val_loss: 2.2907
# Epoch 11/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - accuracy: 0.4357 - loss: 3.5311 - val_accuracy: 0.4823 - val_loss: 2.3235
# Epoch 12/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 238ms/step - accuracy: 0.4502 - loss: 3.3526 - val_accuracy: 0.5272 - val_loss: 2.2268
# Epoch 13/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 305ms/step - accuracy: 0.4486 - loss: 3.1421 - val_accuracy: 0.5154 - val_loss: 2.1829
# Epoch 14/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 230ms/step - accuracy: 0.4590 - loss: 3.0236 - val_accuracy: 0.5319 - val_loss: 2.0376
# Epoch 15/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 258ms/step - accuracy: 0.4731 - loss: 2.7655 - val_accuracy: 0.5485 - val_loss: 2.0126
# Epoch 16/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 254ms/step - accuracy: 0.4731 - loss: 2.6452 - val_accuracy: 0.5390 - val_loss: 2.0306
# Epoch 17/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 378ms/step - accuracy: 0.4804 - loss: 2.5798 - val_accuracy: 0.5461 - val_loss: 1.9173
# Epoch 18/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 332ms/step - accuracy: 0.4748 - loss: 2.5056 - val_accuracy: 0.5319 - val_loss: 1.9581
# Epoch 19/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━
150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - accuracy: 0.7764 - loss: 0.7395 - val_accuracy: 0.6548 - val_loss: 1.0148
# Epoch 127/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 247ms/step - accuracy: 0.7837 - loss: 0.7157 - val_accuracy: 0.6288 - val_loss: 1.0483
# Epoch 128/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 256ms/step - accuracy: 0.7813 - loss: 0.7152 - val_accuracy: 0.6312 - val_loss: 1.0227
# Epoch 129/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 326ms/step - accuracy: 0.7872 - loss: 0.7124 - val_accuracy: 0.6359 - val_loss: 1.0409
# Epoch 130/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - accuracy: 0.7783 - loss: 0.7209 - val_accuracy: 0.6548 - val_loss: 0.9804
# Epoch 131/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 310ms/step - accuracy: 0.7847 - loss: 0.7139 - val_accuracy: 0.6288 - val_loss: 1.0110
# Epoch 132/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - accuracy: 0.7855 - loss: 0.7075 - val_accuracy: 0.6690 - val_loss: 0.9653
# Epoch 133/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 287ms/step - accuracy: 0.7848 - loss: 0.7008 - val_accuracy: 0.6548 - val_loss: 0.9898
# Epoch 134/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 357ms/step - accuracy: 0.7913 - loss: 0.6868 - val_accuracy: 0.6501 - val_loss: 0.9809
# Epoch 135/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 12s 502ms/step - accuracy: 0.7929 - loss: 0.6874 - val_accuracy: 0.6619 - val_loss: 0.9845
# Epoch 136/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 462ms/step - accuracy: 0.7886 - loss: 0.6838 - val_accuracy: 0.6359 - val_loss: 1.0236
# Epoch 137/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - accuracy: 0.7763 - loss: 0.7183 - val_accuracy: 0.6501 - val_loss: 0.9889
# Epoch 138/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 367ms/step - accuracy: 0.7711 - loss: 0.7174 - val_accuracy: 0.6501 - val_loss: 0.9978
# Epoch 139/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 232ms/step - accuracy: 0.7828 - loss: 0.6937 - val_accuracy: 0.6241 - val_loss: 1.0075
# Epoch 140/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - accuracy: 0.7802 - loss: 0.6981 - val_accuracy: 0.6478 - val_loss: 1.0219
# Epoch 141/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 12s 445ms/step - accuracy: 0.7899 - loss: 0.6732 - val_accuracy: 0.6359 - val_loss: 1.0151
# Epoch 142/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 275ms/step - accuracy: 0.7820 - loss: 0.6903 - val_accuracy: 0.6407 - val_loss: 0.9825
# Epoch 143/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 383ms/step - accuracy: 0.7940 - loss: 0.6705 - val_accuracy: 0.6548 - val_loss: 0.9654
# Epoch 144/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 331ms/step - accuracy: 0.7897 - loss: 0.6809 - val_accuracy: 0.6525 - val_loss: 1.0012
# Epoch 145/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 306ms/step - accuracy: 0.7938 - loss: 0.6704 - val_accuracy: 0.6501 - val_loss: 0.9894
# Epoch 146/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 283ms/step - accuracy: 0.7890 - loss: 0.6754 - val_accuracy: 0.6619 - val_loss: 0.9559
# Epoch 147/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 372ms/step - accuracy: 0.7860 - loss: 0.6776 - val_accuracy: 0.6501 - val_loss: 0.9980
# Epoch 148/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 294ms/step - accuracy: 0.7836 - loss: 0.6806 - val_accuracy: 0.6667 - val_loss: 0.9514
# Epoch 149/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 353ms/step - accuracy: 0.7939 - loss: 0.6591 - val_accuracy: 0.6336 - val_loss: 1.0854
# Epoch 150/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 298ms/step - accuracy: 0.7895 - loss: 0.6690 - val_accuracy: 0.6525 - val_loss: 0.9849
# Restoring model weights from the end of the best epoch: 148.

# %%
## Testing the model
CNN_score = CNN.evaluate(X_test, y_test, verbose=0)
print('Test accuracy of the RNN model:',CNN_score[1])
# Out:
# Test accuracy of the RNN model: 0.6546275615692139

# %%
CNN.save('CNN_best.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
